# %% [markdown]
# ## Homework 8 Question 1
# ##### 2022-07-15

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ### Part A

# %%
x = pd.read_csv("MNIST_Subset.csv").to_numpy()
x_reconstructed = x.reshape((x.shape[0], 28, 28))

fig, axs = plt.subplots(1, 5)
for i in range(5):
    axs[i].imshow(x_reconstructed[i], cmap=plt.get_cmap('gray'))
    axs[i].axis('off')

# %% [markdown]
# The numbers displayed are all __fours__. The images are __noisy__.
#
# ### Part B

# %%
U, S, V = np.linalg.svd(x)
x_denoised = np.dot(U[:, :2], np.dot(np.diag(S[:2]), V[:2, :]))
x_denoised = x_denoised.reshape((x_denoised.shape[0], 28, 28))

fig, axs = plt.subplots(2, 5)
for i in range(5):
    axs[0, i].imshow(x_denoised[i], cmap=plt.get_cmap('gray'))
    axs[0, i].axis('off')
    axs[1, i].imshow(x_reconstructed[i], cmap=plt.get_cmap('gray'))
    axs[1, i].axis('off')
